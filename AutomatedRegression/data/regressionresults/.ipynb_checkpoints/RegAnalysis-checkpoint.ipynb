# %%
import pandas as pd

# %%
df = pd.read_csv("finalpool.csv");

# %%
df.head()
# Out:
#   Sensed Species  Rate Constant         L         n        SP    C   R^2
# 0             FC            k23   .287472 -0.681373   11.4286  0.0   1.0
# 1            CIA            k23   .286639 -0.095253   91.9550  0.0   1.0
# 2             F3            k23   .286638 -0.008114  549.4710  0.0   1.0
# 3             F2            kO2   101.012 -1.684860   29.8892  0.0   1.0
# 4             FS            kO2   103.526 -0.012946  264.7000  0.0   1.0

# %%
df
# Out:
#    Sensed Species  Rate Constant              L         n           SP  \
# 0              FC            k23        .287472 -0.681373    11.428600
# 1             CIA            k23        .286639 -0.095253    91.955000
# 2              F3            k23        .286638 -0.008114   549.471000
# 3              F2            kO2        101.012 -1.684860    29.889200
# 4              FS            kO2        103.526 -0.012946   264.700000
# 5              O2            kO2        107.554  9.251680     1.129300
# 6              O2           kcia        4.23162  6.828190     0.851123
# 7              F2           kcia        1.53318 -1.011600    30.000000
# 8              FS           kcia        1.83043 -0.007157   320.786000
# 9              O2           kcyt        1.97599  1.913600     1.067800
# 10             F2           kcyt        3.82253 -1.991710    28.513800
# 11             FS           kcyt        3.82542 -0.015423    84.057100
# ...
